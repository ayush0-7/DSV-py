# %% [markdown]
# Q1. Shopping Cart Item Imagine you're helping build a shopping app. You need to store the name of
# one item.
# • Step 1: Create a variable item_name and store the text "Notebook" in it.
# • Step 2: Print the variable.
# • Step 3: Now change item_name to store a number instead, like 101 (maybe this is now an
# item code).
# • Step 4: Print it again and also print type(item_name) both times.
# Expected output:
# Notebook
# <class 'str'>
# 101
# <class 'int'>
# What this teaches: the same variable can hold different types at different times — no errors, unlike C/
# Java

# %%
item_name = 'Notebook'
print(item_name)
item_name = 101
print(type(item_name))
# Out:
# Notebook
# <class 'int'>

# %% [markdown]
# Q2. Student ID Card You're creating one student's ID card details.
# • Create name (text) = "Ananya"
# • Create roll_number (whole number) = 21
# • Create height_in_cm (decimal number) = 152.5
# • Create is_hostel_student (True/False) = True
# • Print all four values, each on its own line, with a label like Name: Ananya.
# Expected output:
# Name: Ananya
# Roll Number: 21
# Height: 152.5
# Hostel Student: True

# %%
name = 'Ananya'
roll_no = 21
height_in_cm = 152.5
is_hostel_student = True
print('Name : ',name,'\nRoll Number : ',roll_no,'\nHeight : ',height_in_cm,'\nHostel Student : ',is_hostel_student)
# Out:
# Name :  Ananya
# Roll Number :  21
# Height :  152.5
# Hostel Student :  True

# %% [markdown]
# Q3. Comparing Two Friends' Ages Two friends, Sam and Priya, are both 20 years old.
# • Create sam_age = 20 and priya_age = 20.
# • Print sam_age == priya_age — this checks if the values are equal.
# • Print sam_age is priya_age — this checks if they are the exact same object in
# memory.

# %%
sam_age = 20
priya_age = 20


print(sam_age == priya_age)


print(sam_age is priya_age)
# Out:
# True
# True

# %% [markdown]
# Q4. Fixing a Messy Name A user types their name into a form like this: " rohan MEHTA " (extra
# spaces, wrong capitalization).
# • Store this in a variable called raw_name.
# • Use .strip() to remove the extra spaces.
# • Use .title() to capitalize it properly (first letter of each word capital).
# • Print the final cleaned-up name.

# %%
raw_name = " rohan MEHTA "


clean_name = raw_name.strip()


clean_name = clean_name.title()

print(clean_name)
# Out:
# Rohan Mehta

# %% [markdown]
# Q5. Watering Plants Reminder You water your plants every day for 7 days. Write a for loop using
# range()

# %%
for day in range(1, 8):
    print(f"Day {day}: Watered the plant")
# Out:
# Day 1: Watered the plant
# Day 2: Watered the plant
# Day 3: Watered the plant
# Day 4: Watered the plant
# Day 5: Watered the plant
# Day 6: Watered the plant
# Day 7: Watered the plant

# %% [markdown]
# Q6. Counting Down for a Rocket Launch Write a while loop that starts at 5 and counts down to 1,
# printing each number, and finally prints "Blast off!" after the loop ends.

# %%
count = 5

while count >= 1:
    print(count)
    count -= 1

print("Blast off!")
# Out:
# 5
# 4
# 3
# 2
# 1
# Blast off!

# %% [markdown]
# Q7. Movie Ticket Price A cinema charges ₹100 for children (age below 12) and ₹250 for everyone.
# • Create a variable age = 10.
# • Write an if/else statement that prints the correct ticket price based on age.
# • Test it by changing age to 15 and running again

# %%
age = 10

if age < 12:
    print("Ticket Price: ₹100")
else:
    print("Ticket Price: ₹250")
# Out:
# Ticket Price: ₹100

# %% [markdown]
# Q8. Even or Odd Roll Number Write a program that checks if a student's roll number is even or odd
# using %.
# • Create roll_number = 23.
# • If roll_number % 2 == 0, print "Even roll number", otherwise print "Odd
# roll number"

# %%
roll_number = 23

if roll_number % 2 == 0:
    print("Even roll number")
else:
    print("Odd roll number")
# Out:
# Odd roll number

# %% [markdown]
# Q9. Simple Greeting Function Write a function called greet_student(name) that takes a
# name and prints "Hello, <name>! Welcome to Python class."
# • Call the function with "Meera" and then with "Karan".
# Expected output:
# Hello, Meera! Welcome to Python class.
# Hello, Karan! Welcome to Python class.

# %%
def greet_student(name):
    print(f"Hello, {name}! Welcome to Python class.")

greet_student("Meera")
greet_student("Karan")
# Out:
# Hello, Meera! Welcome to Python class.
# Hello, Karan! Welcome to Python class.

# %% [markdown]
# Q10. Add Two Numbers Write a function add_numbers(a, b) that returns the sum of a and b
# (don't just print it inside the function — return it, then print it outside).
# • Call add_numbers(4, 7) and print the result.

# %%
def add_numbers(a, b):
    return a + b

result = add_numbers(4, 7)
print(result)
# Out:
# 11

# %% [markdown]
# Q11. Class Attendance Counter
# • Create a global variable total_students = 0.
# • Write a function mark_present() that increases total_students by 1 — remember
# to use the global keyword inside the function so it can change the global variable.
# • Call mark_present() three times (once for each student who walks in), then print
# total_students.

# %%
total_students = 0
def mark_present():
    global total_students
    total_students += 1
mark_present()
mark_present()
mark_present()
print(total_students)
# Out:
# 3
